# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
testing_data = '../data/testing.csv'
training_data = '../data/training.csv'
validation_data = '../data/validation.csv'

train = pd.read_csv(training_data)
test = pd.read_csv(validation_data)
train.head()
# Out:
#    recordId         drugName                     condition  \
# 0    163740      Mirtazapine                    Depression
# 1    206473       Mesalamine  Crohn's Disease, Maintenance
# 2    159672          Bactrim       Urinary Tract Infection
# 3     39293         Contrave                   Weight Loss
# 4     97768  Cyclafem 1 / 35                 Birth Control
#
#                                        reviewComment                date  \
# 0  "I&#039;ve tried a few antidepressants over th...   February 28, 2012
# 1  "My son has Crohn&#039;s disease and has done ...        May 17, 2009
# 2                      "Quick reduction of symptoms"  September 29, 2017
# 3  "Contrave combines drugs that were used for al...       March 5, 2017
# 4  "I have been on this birth control for one cyc...    October 22, 2015
#
#    usefulCount          sideEffects  rating
# 0           22    Mild Side Effects       5
# 1           17  Severe Side Effects       4
# 2            3      No Side Effects       5
# 3           35    Mild Side Effects       5
# 4            4  Severe Side Effects       5

# %%
data = pd.concat([train, test])
data.head()
# Out:
#    recordId         drugName                     condition  \
# 0    163740      Mirtazapine                    Depression
# 1    206473       Mesalamine  Crohn's Disease, Maintenance
# 2    159672          Bactrim       Urinary Tract Infection
# 3     39293         Contrave                   Weight Loss
# 4     97768  Cyclafem 1 / 35                 Birth Control
#
#                                        reviewComment                date  \
# 0  "I&#039;ve tried a few antidepressants over th...   February 28, 2012
# 1  "My son has Crohn&#039;s disease and has done ...        May 17, 2009
# 2                      "Quick reduction of symptoms"  September 29, 2017
# 3  "Contrave combines drugs that were used for al...       March 5, 2017
# 4  "I have been on this birth control for one cyc...    October 22, 2015
#
#    usefulCount          sideEffects  rating
# 0           22    Mild Side Effects       5
# 1           17  Severe Side Effects       4
# 2            3      No Side Effects       5
# 3           35    Mild Side Effects       5
# 4            4  Severe Side Effects       5

# %%
features = data[['condition', 'usefulCount', 'reviewComment', 'sideEffects']]
target = data['rating']

# %%
features.head()
# Out:
#                       condition  usefulCount  \
# 0                    Depression           22
# 1  Crohn's Disease, Maintenance           17
# 2       Urinary Tract Infection            3
# 3                   Weight Loss           35
# 4                 Birth Control            4
#
#                                        reviewComment          sideEffects
# 0  "I&#039;ve tried a few antidepressants over th...    Mild Side Effects
# 1  "My son has Crohn&#039;s disease and has done ...  Severe Side Effects
# 2                      "Quick reduction of symptoms"      No Side Effects
# 3  "Contrave combines drugs that were used for al...    Mild Side Effects
# 4  "I have been on this birth control for one cyc...  Severe Side Effects

# %%
target.head()
# Out:
# 0    5
# 1    4
# 2    5
# 3    5
# 4    5
# Name: rating, dtype: int64
