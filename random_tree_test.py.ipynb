# %%
from __future__ import division, print_function
import numpy as np
from sklearn import datasets
from utils import train_test_split, accuracy_score, Plot
from random_forest.random_forest_model import RandomForest

# %%
def main():
    data = datasets.load_digits()
    X = data.data
    y = data.target

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, seed=2)
    print("X_train.shape:", X_train.shape)
    print("Y_train.shape:", y_train.shape)

    clf = RandomForest(n_estimators=100)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)

    print("Accuracy:", accuracy)

    Plot().plot_in_2d(X_test, y_pred, title="Random Forest", accuracy=accuracy, legend_labels=data.target_names)

# %%
if __name__ == "__main__":
    main()
# Out:
# X_train.shape: (1079, 64)
# Y_train.shape: (1079,)
# tree 0 fit complete
# tree 1 fit complete
# tree 2 fit complete
# tree 3 fit complete
# tree 4 fit complete
# tree 5 fit complete
# tree 6 fit complete
# tree 7 fit complete
# tree 8 fit complete
# tree 9 fit complete
# tree 10 fit complete
# tree 11 fit complete
# tree 12 fit complete
# tree 13 fit complete
# tree 14 fit complete
# tree 15 fit complete
# tree 16 fit complete
# tree 17 fit complete
# tree 18 fit complete
# tree 19 fit complete
# tree 20 fit complete
# tree 21 fit complete
# tree 22 fit complete
# tree 23 fit complete
# tree 24 fit complete
# tree 25 fit complete
# tree 26 fit complete
# tree 27 fit complete
# tree 28 fit complete
# tree 29 fit complete
# tree 30 fit complete
# tree 31 fit complete
# tree 32 fit complete
# tree 33 fit complete
# tree 34 fit complete
# tree 35 fit complete
# tree 36 fit complete
# tree 37 fit complete
# tree 38 fit complete
# tree 39 fit complete
# tree 40 fit complete
# tree 41 fit complete
# tree 42 fit complete
# tree 43 fit complete
# tree 44 fit complete
# tree 45 fit complete
# tree 46 fit complete
# tree 47 fit complete
# tree 48 fit complete
# tree 49 fit complete
# tree 50 fit complete
# tree 51 fit complete
# tree 52 fit complete
# tree 53 fit complete
# tree 54 fit complete
# tree 55 fit complete
# tree 56 fit complete
# tree 57 fit complete
# tree 58 fit complete
# tree 59 fit complete
# tree 60 fit complete
# tree 61 fit complete
# tree 62 fit complete
# tree 63 fit complete
# tree 64 fit complete
# tree 65 fit complete
# tree 66 fit complete
# tree 67 fit complete
# tree 68 fit complete
# tree 69 fit complete
# tree 70 fit complete
# tree 71 fit complete
# tree 72 fit complete
# tree 73 fit complete
# tree 74 fit complete
# tree 75 fit complete
# tree 76 fit complete
